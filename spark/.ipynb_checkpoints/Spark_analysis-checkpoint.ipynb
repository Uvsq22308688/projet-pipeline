# %%
import requests

es = "http://elasticsearch:9200"
r = requests.get(f"{es}/_cat/indices/api-events-*?v")
print(r.text)
# Out:
# health status index                 uuid                   pri rep docs.count docs.deleted store.size pri.store.size dataset.size
# yellow open   api-events-2026.02.24 PO7hYk1ZQDSZSInd7odLwQ   1   1        168            0    114.8kb        114.8kb      114.8kb

# %%
import requests, pandas as pd

es = "http://elasticsearch:9200"
index = "api-events-*"

query = {
  "size": 1000,
  "query": {"match_all": {}}
}

resp = requests.get(f"{es}/{index}/_search", json=query).json()
hits = [h["_source"] for h in resp["hits"]["hits"]]
df = pd.DataFrame(hits)
df.head()
# Out:
#           timestamp                                              event  temp  \
# 0  2026-02-24T23:45  {'original': '{"city": "Paris", "temp": 10.3, ...  10.3
# 1  2026-02-24T23:45  {'original': '{"city": "Paris", "temp": 10.3, ...  10.3
# 2  2026-02-24T23:45  {'original': '{"city": "Lyon", "temp": 9.6, "d...   9.6
# 3  2026-02-24T23:45  {'original': '{"city": "Paris", "temp": 10.3, ...  10.3
# 4  2026-02-24T23:45  {'original': '{"city": "Paris", "temp": 10.3, ...  10.3
#
#        source   city                @timestamp   description @version
# 0  open-meteo  Paris  2026-02-24T23:45:00.000Z  live_weather        1
# 1  open-meteo  Paris  2026-02-24T23:45:00.000Z  live_weather        1
# 2  open-meteo   Lyon  2026-02-24T23:45:00.000Z  live_weather        1
# 3  open-meteo  Paris  2026-02-24T23:45:00.000Z  live_weather        1
# 4  open-meteo  Paris  2026-02-24T23:45:00.000Z  live_weather        1

# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, avg

spark = SparkSession.builder.appName("api-events").getOrCreate()

sdf = spark.createDataFrame(df)
sdf.groupBy("city").agg(avg("temp").alias("temp_moy")).show()
# Out:
# +-----+------------------+
# | city|          temp_moy|
# +-----+------------------+
# |Paris|10.553333333333331|
# | Lyon| 9.887301587301582|
# +-----+------------------+

# %%
from pyspark.sql.functions import to_timestamp, window

sdf2 = sdf.withColumn("ts", to_timestamp("timestamp"))
sdf2.groupBy(window(col("ts"), "1 hour"), col("city")) \
    .agg(avg("temp").alias("temp_moy")) \
    .orderBy("window") \
    .show(truncate=False)
# Out:
# +------------------------------------------+-----+------------------+
# |window                                    |city |temp_moy          |
# +------------------------------------------+-----+------------------+
# |{2026-02-24 22:00:00, 2026-02-24 23:00:00}|Paris|10.7              |
# |{2026-02-24 22:00:00, 2026-02-24 23:00:00}|Lyon |10.2              |
# |{2026-02-24 23:00:00, 2026-02-25 00:00:00}|Lyon |10.1              |
# |{2026-02-24 23:00:00, 2026-02-25 00:00:00}|Paris|10.700000000000001|
# +------------------------------------------+-----+------------------+

# %%
from pyspark.sql.functions import count, min, max

stats_city = sdf.groupBy("city").agg(
    count("*").alias("nb_events"),
    avg("temp").alias("temp_moy"),
    min("temp").alias("temp_min"),
    max("temp").alias("temp_max")
)

stats_city.show()
# Out:
# +-----+---------+------------------+--------+--------+
# | city|nb_events|          temp_moy|temp_min|temp_max|
# +-----+---------+------------------+--------+--------+
# |Paris|      105|10.553333333333331|    10.3|    10.7|
# | Lyon|       63| 9.887301587301582|     9.6|    10.2|
# +-----+---------+------------------+--------+--------+

# %%
from pyspark.sql.functions import to_timestamp, date_trunc

sdf2 = sdf.withColumn("ts", to_timestamp(col("timestamp")))

ts_hour = sdf2.groupBy(
    "city",
    date_trunc("hour", col("ts")).alias("hour")
).agg(
    avg("temp").alias("temp_moy")
).orderBy("hour")

ts_hour.show(50, truncate=False)
# Out:
# +-----+-------------------+------------------+
# |city |hour               |temp_moy          |
# +-----+-------------------+------------------+
# |Lyon |2026-02-24 22:00:00|10.2              |
# |Paris|2026-02-24 22:00:00|10.7              |
# |Paris|2026-02-24 23:00:00|10.550485436893199|
# |Lyon |2026-02-24 23:00:00|9.882258064516124 |
# +-----+-------------------+------------------+

# %%
from pyspark.sql.window import Window
from pyspark.sql.functions import lag

w = Window.partitionBy("city").orderBy("hour")

delta = ts_hour \
    .withColumn("temp_prev", lag("temp_moy").over(w)) \
    .withColumn("delta_temp", col("temp_moy") - col("temp_prev")) \
    .orderBy("hour", "city")

delta.show(50, truncate=False)
# Out:
# +-----+-------------------+------------------+---------+--------------------+
# |city |hour               |temp_moy          |temp_prev|delta_temp          |
# +-----+-------------------+------------------+---------+--------------------+
# |Lyon |2026-02-24 22:00:00|10.2              |NULL     |NULL                |
# |Paris|2026-02-24 22:00:00|10.7              |NULL     |NULL                |
# |Lyon |2026-02-24 23:00:00|9.882258064516124 |10.2     |-0.3177419354838751 |
# |Paris|2026-02-24 23:00:00|10.550485436893199|10.7     |-0.14951456310680022|
# +-----+-------------------+------------------+---------+--------------------+

# %%
stats_city.coalesce(1).write.mode("overwrite").option("header", True).csv("/home/jovyan/work/results/stats_city")
ts_hour.coalesce(1).write.mode("overwrite").option("header", True).csv("/home/jovyan/work/results/ts_hour")
delta.coalesce(1).write.mode("overwrite").option("header", True).csv("/home/jovyan/work/results/delta_temp")
